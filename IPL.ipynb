# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('/content/ipl1.csv')
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.describe() # Statistical Description
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df['win_by_runs'].max()
# Out:
# 144

# %%
df.sort_values(by='win_by_runs',ascending=False).head()
# By default shows first in Descending order.
# Out:
#       id  season        city        date                        team1  \
# 560  561    2016   Bangalore  14-05-2016  Royal Challengers Bangalore
# 0      1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 497  498    2015   Bangalore  06-05-2015  Royal Challengers Bangalore
# 351  352    2013   Bangalore  23-04-2013  Royal Challengers Bangalore
# 236  237    2011  Dharamsala  17-05-2011              Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 560                Gujarat Lions                Gujarat Lions         field
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 497              Kings XI Punjab              Kings XI Punjab         field
# 351                Pune Warriors                Pune Warriors         field
# 236  Royal Challengers Bangalore              Kings XI Punjab           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.groupby('winner').count()
# Out:
#                              id  season  city  date  team1  team2  \
# winner
# Chennai Super Kings          79      79    77    79     79     79
# Deccan Chargers              29      29    29    29     29     29
# Delhi Daredevils             56      56    55    56     56     56
# Gujarat Lions                 9       9     9     9      9      9
# Kings XI Punjab              63      63    62    63     63     63
# Kochi Tuskers Kerala          6       6     6     6      6      6
# Kolkata Knight Riders        68      68    68    68     68     68
# Mumbai Indians               80      80    80    80     80     80
# Pune Warriors                12      12    12    12     12     12
# Rajasthan Royals             63      63    63    63     63     63
# Rising Pune Supergiants       5       5     5     5      5      5
# Royal Challengers Bangalore  70      70    69    70     70     70
# Sunrisers Hyderabad          34      34    32    34     34     34
#
# ...

# %%
df.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
# Find the missing values
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
plt.plot('win_by_wickets',data=df)
plt.show()

# %%
plt.plot('win_by_runs','*',data=df)
plt.show()

# %%
sns.barplot(x='winner', y='win_by_runs',data=df)
# Out:
# <Axes: xlabel='winner', ylabel='win_by_runs'>

# %%
sns.jointplot(x='result',y='winner',data=df)

# %%
sns.pairplot(df,hue='winner',palette='Purples')

# %%
sns.countplot(x='toss_winner',data=df,hue = 'win_by_wickets')
# Out:
# <Axes: xlabel='toss_winner', ylabel='count'>

# %%
sns.boxplot(x='winner',y='win_by_runs',data=df)
# Out:
# <Axes: xlabel='winner', ylabel='win_by_runs'>

# %%
sns.histplot(x='winner', y = 'city', data=df)
# Out:
# <Axes: xlabel='winner', ylabel='city'>

# %%
sns.displot(x = 'toss_winner', data = df)

# %%
sns.scatterplot(x='team1', y='team2', hue='season', data=df)
plt.show()

# %%
corr=df[['dl_applied','win_by_runs','win_by_wickets']].corr()
print(corr)
sns.heatmap(corr)
# Out:
#                 dl_applied  win_by_runs  win_by_wickets
# dl_applied        1.000000    -0.005878       -0.023803
# win_by_runs      -0.005878     1.000000       -0.572839
# win_by_wickets   -0.023803    -0.572839        1.000000
# <Axes: >

# %%
toss_winner=df['toss_winner']
plt.plot(toss_winner,color='green',label='Toss_winner')
plt.legend()
plt.show()
